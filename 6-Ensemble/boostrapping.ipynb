# %% [markdown]
# ### Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.utils import resample
from sklearn.datasets import fetch_california_housing

# %% [markdown]
# ### Data Collection

# %%
# Load dataset
data = fetch_california_housing()
df = pd.DataFrame(data.data, columns=data.feature_names)
df['Target'] = data.target

# %% [markdown]
# ### Boostrapping

# %%
# Bootstrap sampling: Generate multiple samples
n_samples = 1000
bootstrap_samples = [resample(df, replace=True, random_state=i) for i in range(5)]

# %% [markdown]
# ### Plotting

# %%
# Plot distributions of a feature across bootstrap samples
plt.figure(figsize=(10, 5))
for i, sample in enumerate(bootstrap_samples):
    plt.hist(sample['MedInc'], bins=30, alpha=0.5, label=f"Sample {i+1}")
plt.title("Bootstrap Sampling Distributions of 'MedInc'")
plt.xlabel("Median Income")
plt.ylabel("Frequency")
plt.legend()
plt.show()
